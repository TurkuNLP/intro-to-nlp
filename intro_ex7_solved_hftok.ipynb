# %% [markdown]
# <a href="https://colab.research.google.com/github/TurkuNLP/intro-to-nlp/blob/master/intro_ex7_solved_hftok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sequence labeling (POS tagging) with MLP
#
# This notebook builds upon the [classification with MLP notebook](https://github.com/TurkuNLP/intro-to-nlp/blob/master/mlp_imdb_hf_dset_and_trainer.ipynb) and shows how to implement a basic sequence labeling method.

# %% [markdown]
# ---
#
# # Setup
#
# Install the required Python packages using [pip](https://en.wikipedia.org/wiki/Pip):
#
# * [`transformers`](https://huggingface.co/docs/transformers/index) is a popular deep learning package primarily on top of torch
# * [`datasets`](https://huggingface.co/docs/datasets/) provides support for loading, creating, and manipulating datasets
# * [`evaluate`](https://huggingface.co/docs/evaluate/index) is a library of performance metrics (like accuracy etc)

# %%
# !pip3 install --upgrade transformers[torch]
# !pip3 install -q evaluate
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Collecting transformers[torch]
#   Downloading transformers-5.5.3-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (4.67.3)
# Requirement already satisfied: torch>=2.4 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.10.0+cpu)
# Requirement already satisfied: accelerate>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (1.13.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.1.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->transformers[torch]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->transformers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->transformers[torch]) (3.1.6)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[torch]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[torch]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers[torch]) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers[torch]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers[torch]) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4->transformers[torch]) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers[torch]) (0.1.2)
# Downloading transformers-5.5.3-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 46.7 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed transformers-5.5.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.0 MB/s eta 0:00:00

# %%
import datasets
import evaluate
import transformers

# %% [markdown]
# ---
#
# # Get and prepare data
#
# *   Let us work with the venerable, if somewhat dated [CoNLL'03 shared task](https://aclanthology.org/W03-0419.pdf) English data
# *   These are English news articles, and have annotation for POS, syntactic chunks, and named entities (in the IOB format)
#
# The data as originally distributed for the 2003 shared task has the following format:
#
# ```
# Only RB B-NP O
# France NNP I-NP B-LOC
# and CC I-NP O
# Britain NNP I-NP B-LOC
# backed VBD B-VP O
# Fischler NNP B-NP B-PER
# 's POS I-NP O
# proposal NN I-NP O
# . . O O
# ```
#
# Here, the four space-separated columns are token text, POS tag, chunk tag, and NER tag. The goal of the original task is to predict the NER tags using the other information as features, but the dataset can be used to study predicting the other columns too.
#
# The dataset happens to be in the HF datasets collection, so we can grab it from there

# %%
import torch
import transformers
import datasets

from pprint import pprint    # pretty-print

dataset = datasets.load_dataset("dany0407/conll2003")

print(dataset)
# Out:
# data/train-00000-of-00001.parquet:   0%|          | 0.00/1.22M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/310k [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/281k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/14041 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3250 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/3453 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 14041
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3250
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3453
#     })
# })

# %%
pprint(dataset["train"][12])
# Out:
# {'chunk_tags': [11, 12, 12, 12, 21, 11, 11, 12, 0],
#  'id': '12',
#  'ner_tags': [0, 5, 0, 5, 0, 1, 0, 0, 0],
#  'pos_tags': [30, 22, 10, 22, 38, 22, 27, 21, 7],
#  'tokens': ['Only',
#             'France',
#             'and',
#             'Britain',
#             'backed',
#             'Fischler',
#             "'s",
#             'proposal',
#             '.']}

# %% [markdown]
# As you can see above, the various labels (POS, NER and chunk tags) are converted into IDs in this dataset. We can access the textual labels of these tags through the dataset `features`:

# %%
POS_TAG_NAMES = dataset['train'].features['pos_tags'].feature.names
NER_TAG_NAMES = dataset['train'].features['ner_tags'].feature.names
CHUNK_TAG_NAMES = dataset['train'].features['chunk_tags'].feature.names

# %% [markdown]
# We can then create mappings from names to IDs and back as Python dictionaries:

# %%
POS2ID = { n: i for i, n in enumerate(POS_TAG_NAMES) }
ID2POS = { i: n for i, n in enumerate(POS_TAG_NAMES) }

NER2ID = { n: i for i, n in enumerate(NER_TAG_NAMES) }
ID2NER = { i: n for i, n in enumerate(NER_TAG_NAMES) }

CHUNK2ID = { n: i for i, n in enumerate(CHUNK_TAG_NAMES) }
ID2CHUNK = { i: n for i, n in enumerate(CHUNK_TAG_NAMES) }

# %% [markdown]
# This is what these mappings look like:

# %%
print(NER2ID)
# Out:
# {'O': 0, 'B-PER': 1, 'I-PER': 2, 'B-ORG': 3, 'I-ORG': 4, 'B-LOC': 5, 'I-LOC': 6, 'B-MISC': 7, 'I-MISC': 8}

# %%
print(ID2NER)
# Out:
# {0: 'O', 1: 'B-PER', 2: 'I-PER', 3: 'B-ORG', 4: 'I-ORG', 5: 'B-LOC', 6: 'I-LOC', 7: 'B-MISC', 8: 'I-MISC'}

# %% [markdown]
# Let's also add in explanations from Penn Treebank for the POS tags:

# %%
# From the documentation page and from here https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

POS2DESCRIPTION = {
    "CC": "Coordinating conjunction",
    "CD": "Cardinal number",
    "DT": "Determiner",
    "EX": "Existential there",
    "FW": "Foreign word",
    "IN": "Preposition or subordinating conjunction",
    "JJ": "Adjective",
    "JJR": "Adjective, comparative",
    "JJS": "Adjective, superlative",
    "LS": "List item marker",
    "MD": "Modal",
    "NN": "Noun, singular or mass",
    "NNS": "Noun, plural",
    "NNP": "Proper noun, singular",
    "NNPS": "Proper noun, plural",
    "PDT": "Predeterminer",
    "POS": "Possessive ending",
    "PRP": "Personal pronoun",
    "PRP$": "Possessive pronoun",
    "RB": "Adverb",
    "RBR": "Adverb, comparative",
    "RBS": "Adverb, superlative",
    "RP": "Particle",
    "SYM": "Symbol",
    "TO": "to",
    "UH": "Interjection",
    "VB": "Verb, base form",
    "VBD": "Verb, past tense",
    "VBG": "Verb, gerund or present participle",
    "VBN": "Verb, past participle",
    "VBP": "Verb, non-3rd person singular present",
    "VBZ": "Verb, 3rd person singular present",
    "WDT": "Wh-determiner",
    "WP": "Wh-pronoun",
    "WP$": "Possessive wh-pronoun",
    "WRB": "Wh-adverb"
}

# %% [markdown]
# We can now try to make sense of the tags:

# %%
import tabulate

e = dataset["train"][12]    # work on the same example

table = []
for token, pos_id, chunk_id, ner_id in zip(e["tokens"], e["pos_tags"], e["chunk_tags"], e["ner_tags"]):
    ner_tag = ID2NER[ner_id]
    chunk_tag = ID2CHUNK[chunk_id]
    pos_tag = ID2POS[pos_id]
    pos_def = POS2DESCRIPTION.get(pos_tag,pos_tag)
    table.append([token, ner_tag, chunk_tag, pos_tag, pos_def])

print(tabulate.tabulate(table,headers=["Token", "NER", "Chunk", "POS", "POS definition"]))
# Out:
# Token     NER    Chunk    POS    POS definition
# --------  -----  -------  -----  ------------------------
# Only      O      B-NP     RB     Adverb
# France    B-LOC  I-NP     NNP    Proper noun, singular
# and       O      I-NP     CC     Coordinating conjunction
# Britain   B-LOC  I-NP     NNP    Proper noun, singular
# backed    O      B-VP     VBD    Verb, past tense
# Fischler  B-PER  B-NP     NNP    Proper noun, singular
# 's        O      B-NP     POS    Possessive ending
# proposal  O      I-NP     NN     Noun, singular or mass
# .         O      O        .      .

# %% [markdown]
# Note that the data is organized into sentences.

# %% [markdown]
# ---
#
# # Create features
#
# We'll define a simple function that takes a token sequence, the index of the focus token, and a window size and generates a few basic explicit features relevant to the task.
#
# (Note that as we'll be predicting the POS tag, we won't look at the chunk or NER tags, which would typically only be predicted _after_ predicting POS in a "traditional" NLP pipeline)

# %%
## EXERCISE 7 CODE BELOW - adding postags

def token_features(tokens, postags, index, window_size):
    # Generate features for token in position `index` in given list of tokens
    features = []

    # Context window start and end
    window_start = max(0, index-window_size)
    window_end = min(index+window_size+1, len(tokens))    # note +1 for range

    for i in range(window_start, window_end):
          offset = i - index    # relative position
          features.append(f"token[{offset}]={tokens[i]}")
          features.append(f"postag[{offset}]={ID2POS[postags[i]]}")

    # Example custom feature: does focus token start with an upper-case letter?
    if tokens[index][0].isupper():
        features.append("first-letter-capitalized")

    return features

# %% [markdown]
# We can call this function for all tokens in a sentence like so:

# %%
def add_features_to_sentence(sentence):
    # Collect lists of features for all tokens here
    all_features = []

    tokens = sentence["tokens"]
    postags = sentence["pos_tags"]
    for index in range(len(tokens)):
        all_features.append(" ".join(token_features(tokens, postags, index, window_size=3)))

    return { "features": all_features}

# %%
for feats in add_features_to_sentence(dataset["train"][12])["features"]:
    print(feats)
# Out:
# token[0]=Only postag[0]=RB token[1]=France postag[1]=NNP token[2]=and postag[2]=CC token[3]=Britain postag[3]=NNP first-letter-capitalized
# token[-1]=Only postag[-1]=RB token[0]=France postag[0]=NNP token[1]=and postag[1]=CC token[2]=Britain postag[2]=NNP token[3]=backed postag[3]=VBD first-letter-capitalized
# token[-2]=Only postag[-2]=RB token[-1]=France postag[-1]=NNP token[0]=and postag[0]=CC token[1]=Britain postag[1]=NNP token[2]=backed postag[2]=VBD token[3]=Fischler postag[3]=NNP
# token[-3]=Only postag[-3]=RB token[-2]=France postag[-2]=NNP token[-1]=and postag[-1]=CC token[0]=Britain postag[0]=NNP token[1]=backed postag[1]=VBD token[2]=Fischler postag[2]=NNP token[3]='s postag[3]=POS first-letter-capitalized
# token[-3]=France postag[-3]=NNP token[-2]=and postag[-2]=CC token[-1]=Britain postag[-1]=NNP token[0]=backed postag[0]=VBD token[1]=Fischler postag[1]=NNP token[2]='s postag[2]=POS token[3]=proposal postag[3]=NN
# token[-3]=and postag[-3]=CC token[-2]=Britain postag[-2]=NNP token[-1]=backed postag[-1]=VBD token[0]=Fischler postag[0]=NNP token[1]='s postag[1]=POS token[2]=proposal postag[2]=NN token[3]=. postag[3]=. first-letter-capitalized
# token[-3]=Britain postag[-3]=NNP token[-2]=backed postag[-2]=VBD token[-1]=Fischler postag[-1]=NNP token[0]='s postag[0]=POS token[1]=proposal postag[1]=NN token[2]=. postag[2]=.
# token[-3]=backed postag[-3]=VBD token[-2]=Fischler postag[-2]=NNP token[-1]='s postag[-1]=POS token[0]=proposal postag[0]=NN token[1]=. postag[1]=.
# token[-3]=Fischler postag[-3]=NNP token[-2]='s postag[-2]=POS token[-1]=proposal postag[-1]=NN token[0]=. postag[0]=.

# %% [markdown]
# The dataset is organized into sentences, so we can use the above function to add features to the entire dataset as follows.
#
# **Note**: unlike e.g. the Python`map` function, [`Dataset.map`](https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasets.Dataset.map) function _updates_ its argument dataset, keeping existing values.

# %%
dataset = dataset.map(add_features_to_sentence)
# Out:
# Map:   0%|          | 0/14041 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3250 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3453 [00:00<?, ? examples/s]

# %% [markdown]
# Let's check that one more time:

# %%
pprint(dataset["train"][12])
# Out:
# {'chunk_tags': [11, 12, 12, 12, 21, 11, 11, 12, 0],
#  'features': ['token[0]=Only postag[0]=RB token[1]=France postag[1]=NNP '
#               'token[2]=and postag[2]=CC token[3]=Britain postag[3]=NNP '
#               'first-letter-capitalized',
#               'token[-1]=Only postag[-1]=RB token[0]=France postag[0]=NNP '
#               'token[1]=and postag[1]=CC token[2]=Britain postag[2]=NNP '
#               'token[3]=backed postag[3]=VBD first-letter-capitalized',
#               'token[-2]=Only postag[-2]=RB token[-1]=France postag[-1]=NNP '
#               'token[0]=and postag[0]=CC token[1]=Britain postag[1]=NNP '
#               'token[2]=backed postag[2]=VBD token[3]=Fischler postag[3]=NNP',
#               'token[-3]=Only postag[-3]=RB token[-2]=France postag[-2]=NNP '
#               'token[-1]=and postag[-1]=CC token[0]=Britain postag[0]=NNP '
#               'token[1]=backed postag[1]=VBD token[2]=Fischler postag[2]=NNP '
#               "token[3]='s postag[3]=POS first-letter-capitalized",
#               'token[-3]=France postag[-3]=NNP token[-2]=and postag[-2]=CC '
#               'token[-1]=Britain postag[-1]=NNP token[0]=backed postag[0]=VBD '
#               "token[1]=Fischler postag[1]=NNP token[2]='s postag[2]=POS "
#               'token[3]=proposal postag[3]=NN',
#               'token[-3]=and postag[-3]=CC token[-2]=Britain postag[-2]=NNP '
#               'token[-1]=backed postag[-1]=VBD token[0]=Fischler postag[0]=NNP '
#               "token[1]='s postag[1]=POS token[2]=proposal postag[2]=NN "
#               'token[3]=. postag[3]=. first-letter-capitalized',
#               'token[-3]=Britain postag[-3]=NNP token[-2]=backed '
#               "postag[-2]=VBD token[-1]=Fischler postag[-1]=NNP token[0]='s "
#               'postag[0]=POS token[1]=proposal postag[1]=NN token[2]=. '
#               'postag[2]=.',
#               'token[-3]=backed postag[-3]=VBD token[-2]=Fischler '
#               "postag[-2]=NNP token[-1]='s postag[-1]=POS token[0]=proposal "
#               'postag[0]=NN token[1]=. postag[1]=.',
#               "token[-3]=Fischler postag[-3]=NNP token[-2]='s postag[-2]=POS "
#               'token[-1]=proposal postag[-1]=NN token[0]=. postag[0]=.'],
#  'id': '12',
#  'ner_tags': [0, 5, 0, 5, 0, 1, 0, 0, 0],
#  'pos_tags': [30, 22, 10, 22, 38, 22, 27, 21, 7],
#  'tokens': ['Only',
#             'France',
#             'and',
#             'Britain',
#             'backed',
#             'Fischler',
#             "'s",
#             'proposal',
#             '.']}

# %% [markdown]
# ---
#
# # Flatten dataset
#
# The MLP code that we introduced previously expects each of the `train`, `validation` and `test` subsets of the data to consist of simple sequences of examples.
#
# Now that we have run the feature generation, we no longer need the sentence structure and can "flatten" the data, i.e. remove the "sentence" level of granularity.

# %%
def flatten(subset):
    # Keys for values to flatten
    keys = ["tokens", "pos_tags", "chunk_tags", "ner_tags", "features"]

    # Initialize to empty lists of tokens etc.
    flattened = { k: [] for k in keys }

    # Concatenate per-sentence lists of tokens etc.
    for sentence in subset:
        for key in keys:
            flattened[key].extend(sentence[key])

    # Return as Dataset object
    return datasets.Dataset.from_dict(flattened)

# %% [markdown]
# Call `flatten` for each of the subsets and make a new `DatasetDict` containing the flattened subsets:

# %%
flattened_dict = {
    "train": flatten(dataset["train"]),
    "validation": flatten(dataset["validation"]),
    "test": flatten(dataset["test"]),
}

flat_dataset = datasets.DatasetDict(flattened_dict)

# %% [markdown]
# Check that the new dataset looks OK:

# %%
flat_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 203621
#     })
#     validation: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 51362
#     })
#     test: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 46435
#     })
# })

# %%
for i in range(10):
    token = flat_dataset["train"]["tokens"][i]
    pos_tag = ID2POS[flat_dataset["train"]["pos_tags"][i]]
    description = POS2DESCRIPTION.get(pos_tag, pos_tag)
    features = flat_dataset["train"]["features"][i]
    print(f"{token}\t{pos_tag}\t{description}\t{features}")
# Out:
# EU	NNP	Proper noun, singular	token[0]=EU postag[0]=NNP token[1]=rejects postag[1]=VBZ token[2]=German postag[2]=JJ token[3]=call postag[3]=NN first-letter-capitalized
# rejects	VBZ	Verb, 3rd person singular present	token[-1]=EU postag[-1]=NNP token[0]=rejects postag[0]=VBZ token[1]=German postag[1]=JJ token[2]=call postag[2]=NN token[3]=to postag[3]=TO
# German	JJ	Adjective	token[-2]=EU postag[-2]=NNP token[-1]=rejects postag[-1]=VBZ token[0]=German postag[0]=JJ token[1]=call postag[1]=NN token[2]=to postag[2]=TO token[3]=boycott postag[3]=VB first-letter-capitalized
# call	NN	Noun, singular or mass	token[-3]=EU postag[-3]=NNP token[-2]=rejects postag[-2]=VBZ token[-1]=German postag[-1]=JJ token[0]=call postag[0]=NN token[1]=to postag[1]=TO token[2]=boycott postag[2]=VB token[3]=British postag[3]=JJ
# to	TO	to	token[-3]=rejects postag[-3]=VBZ token[-2]=German postag[-2]=JJ token[-1]=call postag[-1]=NN token[0]=to postag[0]=TO token[1]=boycott postag[1]=VB token[2]=British postag[2]=JJ token[3]=lamb postag[3]=NN
# boycott	VB	Verb, base form	token[-3]=German postag[-3]=JJ token[-2]=call postag[-2]=NN token[-1]=to postag[-1]=TO token[0]=boycott postag[0]=VB token[1]=British postag[1]=JJ token[2]=lamb postag[2]=NN token[3]=. postag[3]=.
# British	JJ	Adjective	token[-3]=call postag[-3]=NN token[-2]=to postag[-2]=TO token[-1]=boycott postag[-1]=VB token[0]=British postag[0]=JJ token[1]=lamb postag[1]=NN token[2]=. postag[2]=. first-letter-capitalized
# lamb	NN	Noun, singular or mass	token[-3]=to postag[-3]=TO token[-2]=boycott postag[-2]=VB token[-1]=British postag[-1]=JJ token[0]=lamb postag[0]=NN token[1]=. postag[1]=.
# .	.	.	token[-3]=boycott postag[-3]=VB token[-2]=British postag[-2]=JJ token[-1]=lamb postag[-1]=NN token[0]=. postag[0]=.
# Peter	NNP	Proper noun, singular	token[0]=Peter postag[0]=NNP token[1]=Blackburn postag[1]=NNP first-letter-capitalized

# %% [markdown]
# Note that this is now a single long dataset of tokens without sentence boundaries.

# %% [markdown]
# # Tokenization
#
# Tokenization needs a bit of thinking, so that we can keep things as simple as possible. We need to turn the strings of features into tokens so that we can then plug them into our MLP.
#
# This would be perfectly doable with the standard tokenizer if only we could convince it to simply tokenize on whitespace and leave everything else untouched.
#
# We cannot use the approach from the MLP lecture, because the pretrained tokenizers tend to modify the data in various ways. We need more control, i.e. we need to make our own tokenizer. Luckily, this is easier than it sounds.

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.pre_tokenizers import WhitespaceSplit
from transformers import PreTrainedTokenizerFast

def build_whitespace_tokenizer(dataset, vocab_size=None, min_frequency=2):
    tokenizer = Tokenizer(WordLevel(unk_token="[UNK]"))

    # Use pure whitespace splitting, no normalization or subwording
    tokenizer.normalizer = None #This is a step which happens before tokenization, we want nothing done. So setting to None.
    tokenizer.pre_tokenizer = WhitespaceSplit() #This is a pre-tokenization step, we want to strictly only use whitespace.

    # List [PAD] first, so it gets index 0
    special_tokens = ["[PAD]","[UNK]"]

    # WordLevelTrainer builds a word-level tokenizer, i.e. no subwords are used, no BPE algorithm, simply full words
    # Words that do not fit into the vocabulary will be replaced by [UNK], which is fine for our purposes
    trainer = WordLevelTrainer(
        vocab_size=vocab_size,
        min_frequency=min_frequency, #only consider tokens which appear this many times
        special_tokens=special_tokens,
    )
    # This is where the actual training happens
    iterator = (example["features"] for example in dataset)
    tokenizer.train_from_iterator(iterator, trainer=trainer)
    print(tokenizer)

    # And this then turns the tokenizer into something we can use
    hf_tokenizer = PreTrainedTokenizerFast(
        tokenizer_object=tokenizer,

        unk_token="[UNK]",
        pad_token="[PAD]",
    )

    return hf_tokenizer
tokenizer = build_whitespace_tokenizer(flat_dataset["train"], vocab_size=15000)
# Out:
# Tokenizer(version="1.0", truncation=None, padding=None, added_tokens=[{"id":0, "content":"[PAD]", "single_word":False, "lstrip":False, "rstrip":False, ...}, {"id":1, "content":"[UNK]", "single_word":False, "lstrip":False, "rstrip":False, ...}], normalizer=None, pre_tokenizer=WhitespaceSplit(), post_processor=None, decoder=None, model=WordLevel(vocab={"[PAD]":0, "[UNK]":1, "first-letter-capitalized":2, "postag[0]=NNP":3, "postag[-1]=NNP":4, ...}, unk_token="[UNK]"))

# %%
tokenizer.vocab
# Out:
# {'token[0]=single': 6692,
#  'token[2]=place': 2970,
#  'token[-2]=using': 13483,
#  'token[-3]=union': 8054,
#  'token[2]=drove': 9265,
#  'token[1]=full': 6141,
#  'token[0]=airports': 13727,
#  'token[-1]=F.C.': 10599,
#  'token[-1]=saying': 1887,
#  'token[1]=beat': 585,
#  'token[0]=3-1': 10929,
#  'token[1]=Australia': 1103,
#  'token[-3]=Catholic': 11631,
#  'token[0]=Catholic': 11744,
#  'token[2]=Muster': 11195,
#  'token[-2]=Baghdad': 9446,
#  'token[-1]=guilty': 14461,
#  'token[-2]=high': 4446,
#  'token[-1]=executive': 6533,
#  'token[3]=Sanchez': 9890,
#  'token[-1]=team': 1556,
#  'token[-1]=KANSAS': 6515,
#  'token[-1]=Hill': 12239,
#  'token[-2]=women': 3392,
#  'token[3]=special': 9930,
#  'token[-2]=head': 3646,
#  'token[3]=previous': 4686,
#  'token[1]=call': 5102,
#  'token[1]=nothing': 10383,
#  'token[2]=Finland': 4107,
#  'token[1]=Chechnya': 4492,
#  'token[0]=Scores': 11779,
#  'token[-3]=who': 488,
#  'token[-1]=St': 2487,
#  'token[0]=small': 5089,
#  'token[2]=53': 7410,
#  'token[0]=Beijing': 10232,
#  'token[0]=its': 632,
#  'token[2]=final': 2164,
#  'token[-3]=truck': 9045,
#  'token[-2]=made': 1329,
#  'token[-2]=Jamaica': 13367,
#  'token[-3]=Nice': 14792,
#  'token[-1]=cents': 2488,
#  'token[0]=Andre': 13649,
#  'token[-1]=Democrats': 8313,
#  'token[-1]=line': 6540,
#  'token[2]=economy': 6767,
#  'token[-1]=York': 1970,
#  'token[-1]=annual': 9399,
#  'token[1]=worth': 8677,
#  'token[-3]=Zealand': 3926,
#  'postag[-3]=FW': 1082,
#  'token[0]=soldier': 12781,
#  'token[-1]=BALTIMORE': 7158,
#  'token[1]=boy': 10354,
#  'token[2]=demand': 3271,
#  'token[-1]=54': 5972,
#  'token[-3]=address': 11676,
#  'token[-1]=with': 323,
#  'token[0]=50,000': 12649,
#  'token[-1]=opposed': 13288,
#  'token[2]=admitted': 9815,
#  'token[1]=CHAMPIONSHIP': 10333,
#  'token[3]=below': 14208,
#  'token[0]=always': 7680,
#  'token[3]=teams': 10568,
#  'token[0]=The': 285,
#  'token[-3]=Fortuna': 10152,
#  'token[-1]=around': 1781,
#  'token[1]=A.': 7713,
#  'token[3]=anything': 11311,
#  'token[3]=release': 8771,
#  'token[2]=trading': 3697,
#  'token[-1]=Juan': 8806,
#  'token[-2]=investors': 7982,
#  'token[-1]=Pakistani': 12260,
#  'token[2]=thousands': 12091,
#  'token[1]=action': 5299,
#  'token[-3]=immediate': 12604,
#  'token[0]=got': 5278,
#  'token[2]=rupiah': 13014,
#  'token[-1]=nine': 3836,
#  'token[2]=Minister': 1336,
#  'token[-3]=Khartoum': 12541,
#  'token[2]=Zimbabwe': 12020,
#  'token[-2]=2000': 12362,
#  'token[3]=1996-08-22': 9871,
#  'token[0]=Canadian': 7659,
#  'token[3]=Bill': 10499,
#  'token[0]=Saturday': 1080,
#  'token[2]=positions': 12074,
#  'token[1]=profits': 7391,
#  'token[2]=6-1': 2127,
#  'token[-2]=lap': 11581,
#  'token[-2]=69': 1889,
#  'token[-2]=offered': 8952,
#  'token[-1]=broke': 6527,
#  'token[1]=California': 6384,
#  'token[3]=without': 4415,
#  'token[2]=wickets': 4266,
#  'token[-1]=Lewis': 7165,
#  'token[0]=terms': 9140,
#  'token[-1]=likely': 5011,
#  'token[-1]=also': 764,
#  'token[3]=Bob': 14164,
#  'token[-1]=convention': 5541,
#  'token[-1]=mad': 11465,
#  'token[2]=looked': 10464,
#  'token[-3]=54': 12505,
#  'token[0]=GDP': 14985,
#  'token[3]=New': 1324,
#  'token[1]=offices': 12887,
#  'token[-1]=guerrillas': 4846,
#  'token[-2]=majority': 9504,
#  'token[2]=though': 12090,
#  'token[1]=admitted': 9742,
#  'token[-1]=35': 9938,
#  'token[0]=Arantxa': 13650,
#  'token[1]=comment': 5876,
#  'token[-3]=three-run': 14928,
#  'token[1]=rising': 11959,
#  'token[0]=firm': 6677,
#  'token[-2]=oil': 3745,
#  'postag[0]=,': 63,
#  'token[0]=6-': 11734,
#  'token[2]=sides': 8236,
#  'token[3]=used': 5967,
#  'token[0]=attacks': 6092,
#  'token[1]=about': 836,
#  'token[1]=Cuba': 9154,
#  'token[2]=50': 2126,
#  'token[-2]=rate': 2659,
#  'token[-3]=currently': 10180,
#  'token[-1]=study': 14512,
#  'token[2]=child': 8702,
#  'token[-1]=Fiorentina': 14336,
#  'token[-1]=francs': 7913,
#  'token[1]=bond': 6398,
#  'token[1]=am': 9743,
#  'token[-2]=figure': 12446,
#  'token[-2]=1991': 8385,
#  'token[2]=real': 14116,
#  'token[0]=SAN': 2946,
#  'token[-2]=Philip': 12405,
#  'token[1]=where': 1384,
#  'token[2]=caused': 10435,
#  'token[0]=heart': 10291,
#  'token[-2]=Boardman': 13344,
#  'token[-2]=Wilson': 14619,
#  'token[2]=less': 6447,
#  'token[-3]=BASEBALL': 4605,
#  'token[-2]=family': 10101,
#  'token[1]=52': 9709,
#  'token[-3]=60': 4604,
#  'token[-2]=Chechnya': 5206,
#  'token[-1]=NOTE': 10620,
#  'token[0]=share': 3495,
#  'token[1]=tax': 7399,
#  'token[-3]=behind': 4457,
#  'token[-1]=soon': 5379,
#  'token[-1]=peace': 1647,
#  'token[-3]=houses': 11694,
#  'token[2]=3-6': 7765,
#  'token[2]=talk': 6784,
#  'token[-2]=workers': 5588,
#  'token[1]=say': 2368,
#  'token[3]=real': 14275,
#  'token[-1]=shares': 1428,
#  'postag[2]=RB': 113,
#  'token[-3]=All': 8463,
#  'token[-3]=take': 1816,
#  'token[3]=call': 5516,
#  'token[-1]=cancelled': 14421,
#  'token[0]=dealer': 8567,
#  'token[-1]=large': 10663,
#  'token[-3]=last': 725,
#  'token[1]=opening': 5112,
#  'token[0]=I': 624,
#  'token[-3]=subject': 13625,
#  'token[0]=player': 7027,
#  'token[-1]=state': 1066,
#  'token[-1]=English': 3632,
#  'token[1]=Bill': 6707,
#  'token[1]=Mullally': 6126,
#  'token[-3]=whether': 3330,
#  'token[0]=96': 3937,
#  'token[3]=votes': 8303,
#  'token[-1]=9': 1223,
#  'token[1]=talks': 1687,
#  'token[3]=champion': 2335,
#  'token[0]=China': 1432,
#  'token[3]=heavy': 11327,
#  'token[-1]=potential': 14489,
#  'token[2]=fired': 12048,
#  'token[-2]=96': 4581,
#  'token[2]=value': 8242,
#  'token[-1]=top': 2786,
#  'token[1]=but': 518,
#  'token[2]=filed': 12047,
#  'token[2]=Todd': 10426,
#  'token[3]=data': 13088,
#  'token[-2]=stage': 8450,
#  'token[-3]=Aug': 13501,
#  'token[3]=loss': 3896,
#  'token[0]=thing': 12787,
#  'token[-3]=Poland': 6948,
#  'token[2]=64': 3684,
#  'token[-3]=Republican': 5594,
#  'token[1]=Gary': 12812,
#  'token[1]=63': 3875,
#  'token[-3]=slightly': 10913,
#  'token[-3]=league': 3155,
#  'token[-3]=too': 7650,
#  'token[1]=News': 12827,
#  'token[1]=bank': 2462,
#  'token[1]=managed': 12883,
#  'token[2]=states': 9858,
#  'token[-1]=possible': 4702,
#  'token[1]=asked': 3590,
#  'token[-2]=their': 565,
#  'token[0]=seventh': 9697,
#  'token[2]=sale': 8724,
#  'token[1]=CHICAGO': 12805,
#  'token[1]=Max': 13871,
#  'token[1]=whom': 12916,
#  'token[-1]=Richard': 7167,
#  'token[-1]=diplomats': 12303,
#  'token[3]=lost': 1762,
#  'token[0]=consumer': 10277,
#  'token[-3]=Michael': 3088,
#  'token[-1]=weapons': 7555,
#  'token[2]=straight': 5925,
#  'token[-3]=Ireland': 5810,
#  'token[3]=charged': 6468,
#  'token[-3]=has': 397,
#  'token[-1]=sought': 10038,
#  'token[0]=loss': 3337,
#  'token[-1]=killing': 6869,
#  'token[-1]=Surrey': 11419,
#  'token[3]=cuts': 14223,
#  'token[-2]=guilty': 14672,
#  'token[1]=unless': 6422,
#  'token[-1]=through': 1306,
#  'token[0]=25': 2086,
#  'token[-1]=R.': 7891,
#  'token[0]=speaker': 13801,
#  'token[2]=Rica': 8210,
#  'token[2]=scandal': 14122,
#  'token[2]=Paulo': 12007,
#  'token[-3]=TEXAS': 13537,
#  'token[1]=banks': 7046,
#  'token[2]=qualifier': 9282,
#  'token[-3]=County': 11632,
#  'token[3]=Saturday': 1263,
#  "token[3]='": 1055,
#  'token[-3]=verified': 8055,
#  'postag[-1]=:': 212,
#  'token[0]=171': 7295,
#  'token[-3]=Rotterdam': 12557,
#  'token[1]=Swiss': 10347,
#  'token[-2]=heard': 14673,
#  'token[-2]=denotes': 7586,
#  'token[1]=one-day': 9208,
#  'token[0]=Barcelona': 9624,
#  'token[-1]=found': 2274,
#  'token[-2]=television': 3651,
#  'token[1]=1990': 7346,
#  'token[1]=date': 5104,
#  'token[2]=Richard': 14033,
#  'token[-3]=concern': 10178,
#  'token[0]=reporters': 3338,
#  'token[2]=parliament': 3441,
#  'token[-2]=Health': 11515,
#  'token[-3]=21': 1443,
#  'token[-1]=far': 6866,
#  'token[3]=session': 14285,
#  'token[0]=race': 2514,
#  'token[0]=main': 3674,
#  'token[-1]=allegations': 12284,
#  'token[3]=February': 7826,
#  'token[3]=Lloyd': 7830,
#  'token[-2]=power': 3746,
#  'postag[1]=VBN': 95,
#  'token[-1]=coalition': 7524,
#  'token[-2]=vs.': 2444,
#  'token[2]=East': 4371,
#  'token[-1]=leads': 14475,
#  'token[-3]=afternoon': 14831,
#  'token[0]=foot': 11816,
#  'token[0]=media': 9688,
#  'token[-1]=holiday': 5370,
#  'token[-2]=rates': 5793,
#  'token[1]=fiscal': 11127,
#  'token[-2]=Centre': 14544,
#  'token[2]=difficult': 9264,
#  "token[3]='m": 12098,
#  'token[3]=accused': 4809,
#  'token[2]=plans': 3808,
#  'token[3]=1997': 3810,
#  'token[3]=U.N.': 5154,
#  'token[2]=army': 4251,
#  'token[-1]=Scottish': 13213,
#  'token[3]=AT': 5336,
#  'token[1]=gold': 5878,
#  'token[-3]=Liberia': 14784,
#  'token[3]=eighth': 10536,
#  'token[2]=one': 719,
#  'token[0]=Orioles': 11773,
#  'token[-3]=Inc': 3086,
#  'token[-3]=Inc.': 13517,
#  'token[-2]=Cork': 10716,
#  "token[-2]='m": 6015,
#  'token[-2]=have': 453,
#  'token[1]=Saturday': 1097,
#  'token[2]=released': 4385,
#  'token[-3]=BSE': 13502,
#  'token[-1]=neighbouring': 13286,
#  'token[-2]=met': 6285,
#  'token[-3]=Bank': 2183,
#  'token[-2]=big': 6268,
#  'token[-1]=included': 7536,
#  'token[1]=championships': 10355,
#  'token[3]=Egypt': 9304,
#  'token[2]=software': 14127,
#  'token[-3]=They': 1596,
#  'token[2]=pounds': 6778,
#  'token[-1]=services': 6242,
#  'token[-2]=away': 3738,
#  'token[2]=attacks': 6431,
#  'token[3]=purchase': 14269,
#  'token[-3]=average': 5241,
#  'token[1]=Burundi': 11874,
#  'token[3]=evening': 9906,
#  'token[3]=join': 11334,
#  'token[-3]=Thai': 6952,
#  'token[2]=San': 7783,
#  'token[0]=may': 3248,
#  'token[-2]=Iran': 5558,
#  'token[3]=point': 5349,
#  'token[3]=traded': 8778,
#  'token[2]=might': 4380,
#  'token[-1]=flew': 13264,
#  'token[-2]=legal': 7984,
#  'token[1]=Iranian': 7042,
#  'token[2]=grand': 11238,
#  'token[-3]=wants': 11728,
#  'postag[1]=VBP': 250,
#  'token[1]=Nigeria': 6712,
#  'token[-2]=most': 2019,
#  'token[1]=husband': 9201,
#  'token[-3]=bonds': 7260,
#  'token[0]=abandoned': 12717,
#  'token[2]=national': 3614,
#  'token[-3]=Venezuela': 9562,
#  'token[3]=as': 377,
#  'token[0]=broke': 6669,
#  'token[-1]=living': 13279,
#  'token[1]=rival': 8664,
#  'token[2]=anything': 11221,
#  'token[0]=Nicaraguan': 11771,
#  'token[0]=against': 730,
#  'token[-1]=Extras': 9371,
#  'token[2]=possible': 4796,
#  "token[2]=n't": 1424,
#  'token[-2]=official': 1283,
#  'token[2]=Yellow': 11214,
#  'token[-1]=Malik': 11398,
#  'token[3]=risk': 8295,
#  'token[-1]=calls': 14420,
#  'token[0]=official': 1242,
#  'token[1]=Czech': 2361,
#  'token[3]=Saudi': 8265,
#  'token[1]=candidate': 12850,
#  'token[3]=billion': 1544,
#  'token[-1]=PARIS': 4999,
#  'token[2]=local': 2374,
#  'token[-1]=Polish': 6849,
#  'token[-1]=double': 7530,
#  'token[0]=326': 6644,
#  'token[-3]=Boston': 10143,
#  'token[0]=5,000': 14952,
#  'token[3]=scandal': 14282,
#  'token[-3]=After': 6050,
#  'token[0]=This': 3488,
#  'token[-2]=following': 3143,
#  'token[1]=Japanese': 5870,
#  'postag[-1]=WP$': 6494,
#  'token[2]=winners': 12097,
#  'token[-1]=lost': 1350,
#  'token[-2]=Burundi': 10052,
#  'token[2]=road': 5922,
#  'token[0]=around': 1793,
#  'token[-1]=manager': 4297,
#  'token[-1]=qualifying': 10675,
#  'token[0]=Louis': 8545,
#  'token[1]=sixth': 8191,
#  'token[1]=Louis': 9162,
#  'token[2]=+31': 11976,
#  'token[3]=you': 2436,
#  'token[-2]=And': 11499,
#  'token[-3]=below': 13549,
#  'token[0]=Bayern': 12660,
#  'token[-2]=conflict': 13413,
#  'token[1]=boost': 12849,
#  'postag[-3]=,': 83,
#  'token[2]=stages': 12086,
#  'token[0]=director': 6358,
#  'token[1]=men': 3263,
#  'token[-3]=Japanese': 5407,
#  'token[-3]=game': 2148,
#  'token[2]=ruling': 14121,
#  'token[0]=residents': 13795,
#  'token[-2]=hand': 10107,
#  'token[3]=return': 3525,
#  'token[2]=join': 11243,
#  'token[2]=Korea': 14021,
#  'token[-1]=title': 5551,
#  'token[1]=Malta': 12823,
#  'token[1]=straight': 5670,
#  'token[1]=look': 11139,
#  'token[-3]=market': 1179,
#  'token[-1]=prime': 4301,
#  'token[1]=airport': 4496,
#  'token[-3]=disease': 5603,
#  'token[-1]=Barcelona': 9360,
#  'token[1]=TEST': 11900,
#  'token[-2]=since': 1053,
#  'token[-1]=6.0': 13153,
#  'token[3]=half': 1710,
#  'token[-3]=Three': 13539,
#  'token[1]=82': 11868,
#  'token[3]=coming': 5945,
#  'token[1]=Peter': 6713,
#  'token[0]=scheduled': 5641,
#  'token[-1]=km': 3138,
#  'token[0]=Gloucestershire': 13671,
#  'token[3]=1996-08-24': 11279,
#  'token[-2]=just': 1282,
#  'token[1]=Croatia': 9713,
#  'token[-1]=work': 3304,
#  'token[0]=incident': 12753,
#  'token[1]=interim': 11132,
#  'token[2]=opening': 5139,
#  'token[0]=am': 9663,
#  'token[-2]=Nicaraguan': 11527,
#  'token[0]=village': 6378,
#  'token[1]=control': 4090,
#  'token[-1]=69': 1615,
#  'token[1]=Russia': 1750,
#  'token[0]=minute': 2121,
#  'token[-2]=Marcelo': 10070,
#  'token[-3]=6': 1156,
#  'token[-2]=Simon': 13390,
#  'token[-3]=round': 1843,
#  'token[0]=Exchange': 5623,
#  'token[-2]=65': 3731,
#  'token[-1]=accept': 11425,
#  'token[1]=shareholders': 11153,
#  'token[2]=7-6': 2037,
#  'token[-1]=material': 13280,
#  'token[-1]=forced': 4845,
#  'token[0]=stage': 6373,
#  'token[-2]=tough': 13480,
#  'token[2]=tax': 7816,
#  'token[-1]=price': 2710,
#  'token[3]=Medvedev': 12119,
#  'token[-2]=Bill': 6560,
#  'token[3]=1996-08-25': 6459,
#  "token[-1]='ll": 7869,
#  'token[-1]=Wilson': 13229,
#  'token[0]=asked': 3575,
#  'token[1]=Hong': 3344,
#  'token[1]=truck': 8674,
#  'token[1]=stocks': 7398,
#  'token[-1]=Dhaka': 12230,
#  'token[1]=General': 7041,
#  'token[2]=1993': 9787,
#  'token[0]=least': 4344,
#  'token[3]=governor': 9328,
#  'token[-2]=traffic': 8974,
#  'token[-1]=FOR': 5976,
#  'token[-1]=leadership': 12324,
#  'token[1]=strike': 3967,
#  'token[0]=billion': 1536,
#  'token[-1]=Finland': 3376,
#  'token[-2]=draft': 13428,
#  'token[0]=a.m.': 9660,
#  'token[-1]=Slam': 13217,
#  'token[-1]=Toyota': 10628,
#  'token[1]=73': 3030,
#  'token[-3]=3': 435,
#  'token[-1]=Bangladesh': 12220,
#  'token[1]=6.0': 11060,
#  'token[-3]=Anwar': 9536,
#  'token[3]=raised': 14273,
#  'token[-1]=estimated': 5008,
#  'token[2]=taken': 3695,
#  'token[-3]=Germany': 1411,
#  'token[1]=condition': 8168,
#  'token[-1]=Machado': 14354,
#  'token[3]=fell': 4129,
#  'token[2]=ninth': 7101,
#  'token[-1]=media': 9422,
#  'token[-2]=Fox': 12381,
#  'token[-3]=port': 9598,
#  'token[1]=here': 6144,
#  'postag[-3]=JJS': 720,
#  'token[2]=1991': 7070,
#  'token[0]=BASEBALL': 4618,
#  'token[1]=WORLD': 8628,
#  'token[0]=scores': 9696,
#  'token[0]=Mushtaq': 5434,
#  'token[3]=Nations': 5710,
#  'token[0]=CALIFORNIA': 8068,
#  'token[-1]=last': 667,
#  'token[-2]=settlement': 7991,
#  'token[0]=operation': 9125,
#  'token[0]=Wayne': 9090,
#  'token[2]=medical': 9845,
#  'token[1]=Lebanon': 11077,
#  'token[-3]=--': 581,
#  'token[3]=Slovak': 14193,
#  'token[-1]=reserve': 13299,
#  'token[0]=49': 10230,
#  'token[2]=control': 4115,
#  'token[-1]=common': 9406,
#  'token[-1]=off': 1127,
#  'token[-1]=63': 3828,
#  'token[-1]=children': 4570,
#  'token[-1]=without': 4022,
#  'token[0]=rounds': 8595,
#  'token[-2]=vice': 14730,
#  'token[3]=using': 14301,
#  'token[3]=orders': 9918,
#  'token[-2]=Lanka': 4860,
#  'token[-1]=Interior': 14346,
#  'token[0]=face': 4917,
#  'token[-3]=Hansa': 14774,
#  'token[3]=Akram': 5708,
#  'token[-2]=Younis': 8922,
#  'token[0]=CENTRAL': 9630,
#  'token[-2]=separatists': 14710,
#  'token[-3]=when': 758,
#  'token[1]=because': 1192,
#  'token[-2]=Argentina': 6254,
#  'token[1]=passenger': 9771,
#  'token[0]=mother': 13780,
#  'token[-3]=offered': 9594,
#  'token[-3]=Wimbledon': 6310,
#  'token[-1]=date': 5005,
#  'token[0]=help': 4212,
#  'token[-1]=Martinez': 9380,
#  'token[2]=death': 4964,
#  'token[0]=150': 13640,
#  'token[-2]=Supreme': 14612,
#  'token[2]=ban': 4253,
#  'token[2]=will': 543,
#  'token[-1]=Louis': 8323,
#  'token[2]=born': 14058,
#  'token[1]=Greg': 11881,
#  'token[1]=residents': 13964,
#  'token[-2]=discuss': 7225,
#  'token[1]=Islamist': 12815,
#  'token[-3]=certain': 14848,
#  'token[-2]=nuclear': 5792,
#  'token[-3]=scattered': 14912,
#  'token[-1]=Berlin': 8792,
#  'token[1]=Eindhoven': 11070,
#  'token[-2]=Gloucestershire': 13360,
#  'token[3]=during': 1761,
#  'token[0]=rights': 3775,
#  'token[-3]=Ministry': 4886,
#  'token[1]=EPS': 13851,
#  'token[3]=ransom': 12183,
#  'token[2]=tonne': 7817,
#  'token[-1]=Akram': 4138,
#  'token[-3]=Algerian': 12513,
#  'token[-2]=SECOND': 14605,
#  'token[1]=N.': 12826,
#  'token[1]=rules': 9217,
#  'token[2]=Stich': 12955,
#  'token[-3]=ethnic': 9584,
#  'token[0]=King': 8542,
#  'token[1]=administration': 10350,
#  'token[-1]=TO': 5535,
#  'postag[-3]=NNPS': 401,
#  'token[1]=offered': 8178,
#  'token[-2]=become': 7577,
#  'token[3]=so': 2047,
#  'token[2]=military': 2528,
#  'token[-2]=has': 393,
#  'token[0]=move': 8583,
#  'token[3]=wickets': 5734,
#  'token[0]=big': 6353,
#  'token[-1]=80': 8788,
#  'token[-1]=British': 1503,
#  'token[-1]=distribution': 13252,
#  'token[-3]=July': 1790,
#  'token[2]=rain': 8232,
#  'token[2]=export': 12046,
#  'token[-2]=Ethiopia': 14557,
#  'token[-2]=CHICAGO': 5557,
#  'token[3]=copper': 9903,
#  'token[3]=source': 7142,
#  'token[3]=Service': 10513,
#  'token[-2]=Khartoum': 12392,
#  'token[0]=crowd': 11805,
#  'token[-3]=record': 3326,
#  'token[3]=declared': 6810,
#  'token[-1]=57': 8306,
#  'postag[1]=NNPS': 369,
#  'token[0]=December': 8071,
#  'token[2]=biggest': 10432,
#  'token[-2]=World': 2389,
#  'token[-3]=months': 3397,
#  'token[-1]=Court': 7505,
#  'token[-2]=There': 2549,
#  'token[3]=100': 2531,
#  'token[1]=Sweden': 1820,
#  'token[0]=Ajax': 4471,
#  'token[2]=does': 4376,
#  'token[2]=seek': 10480,
#  'token[-3]=arrested': 3563,
#  'token[2]=get': 2824,
#  'token[3]=a.m.': 12138,
#  'token[-1]=management': 8357,
#  'token[0]=ministers': 11018,
#  'token[0]=books': 9667,
#  'token[2]=82': 12922,
#  'token[0]=questioned': 12767,
#  'token[-3]=daily': 6058,
#  'token[-1]=software': 12348,
#  'token[-3]=third': 1479,
#  'token[0]=Max': 13689,
#  'token[1]=20': 1400,
#  'token[-3]=face': 5414,
#  'token[2]=past': 3807,
#  'token[2]=Younis': 7787,
#  'token[3]=LEAGUE': 3522,
#  'token[-3]=SOCCER': 1046,
#  'token[2]=current': 3973,
#  'token[2]=boy': 12970,
#  'token[-3]=51': 12504,
#  'token[-1]=Gore': 9957,
#  'token[1]=Malaysia': 12822,
#  'token[1]=spoke': 13973,
#  'token[2]=Australia': 1165,
#  'token[0]=order': 4484,
#  'token[2]=tennis': 5507,
#  'token[0]=Japan': 1515,
#  'token[3]=deal': 2643,
#  'token[0]=important': 7022,
#  'token[-3]=within': 5620,
#  'token[-2]=wins': 14735,
#  'token[2]=championship': 3435,
#  'token[1]=1996': 1171,
#  'token[-3]=firm': 6967,
#  'token[-1]=Warwickshire': 13228,
#  'token[-3]=grand': 13586,
#  'token[1]=concern': 9189,
#  'postag[-2]=VB': 93,
#  'token[0]=46': 6645,
#  'token[-1]=witnesses': 14525,
#  'token[-1]=Fox': 12235,
#  'token[-2]=sprint': 14716,
#  'token[-3]=scheduled': 5615,
#  'token[1]=failed': 4233,
#  'token[-2]=England': 1459,
#  'token[-2]=export': 12445,
#  'token[1]=DUTCH': 11879,
#  'token[1]=prices': 2419,
#  'token[-1]=Ethiopia': 14332,
#  'token[-1]=Yugoslavia': 8828,
#  'token[-2]=millions': 12464,
#  'token[1]=paid': 8657,
#  'token[0]=Finland': 3405,
#  'token[-3]=South': 1330,
#  'token[-3]=FIRST': 2858,
#  'token[-2]=rival': 8444,
#  'token[-3]=carry': 14846,
#  'token[-3]=charge': 8490,
#  'token[0]=Association': 6079,
#  'token[-3]=general': 3659,
#  'token[-3]=Atherton': 13500,
#  'token[0]=Graf': 9642,
#  'token[0]=member': 8110,
#  'token[3]=3-0': 12103,
#  'token[1]=Chechen': 8143,
#  'token[-1]=Nice': 14366,
#  'token[3]=double': 8758,
#  'token[1]=press': 4647,
#  'token[3]=soon': 5731,
#  'postag[2]=PRP$': 247,
#  'token[-2]=fourth': 4596,
#  'token[0]=very': 2260,
#  'token[0]=chief': 2948,
#  'token[3]=period': 4545,
#  'token[-3]=miles': 2862,
#  'token[2]=settlement': 7450,
#  'token[2]=made': 1423,
#  'token[-1]=air': 7172,
#  'token[3]=negotiations': 7857,
#  'token[-2]=Sudan': 6900,
#  'token[-1]=Congress': 8796,
#  'token[0]=*': 5068,
#  'token[2]=heard': 14084,
#  'token[-3]=Jose': 6943,
#  'token[3]=while': 1527,
#  'token[1]=Hill': 13855,
#  'token[-3]=73': 4183,
#  'token[0]=Slovakia': 4626,
#  'token[-3]=Schalke': 13534,
#  'token[0]=financial': 5444,
#  'token[0]=system': 6375,
#  'token[-1]=Moscow': 2437,
#  'token[2]=analyst': 8697,
#  'token[-3]=Yankees': 12569,
#  'token[-2]=run': 2394,
#  'token[3]=Romania': 5711,
#  'token[-3]=Gore': 11645,
#  'token[2]=community': 9823,
#  'token[-3]=grain': 12599,
#  'token[-3]=worth': 8523,
#  'token[1]=doing': 8641,
#  'token[0]=arrest': 9099,
#  'token[0]=keep': 5855,
#  'token[-1]=5.': 2207,
#  'token[2]=Brazil': 3969,
#  'token[3]=Costa': 5934,
#  'token[-2]=homes': 11574,
#  'token[-1]=Sweden': 1713,
#  'token[3]=13': 1567,
#  "postag[-2]=''": 6829,
#  'token[1]=member': 8176,
#  'token[3]=we': 986,
#  'token[1]=it': 400,
#  'token[-2]=political': 1977,
#  'token[-2]=customs': 12437,
#  'token[3]=took': 2304,
#  'token[-1]=if': 1407,
#  'token[1]=battle': 9185,
#  'token[2]=last': 677,
#  'token[0]=saying': 1901,
#  'token[-3]=ENGLISH': 8013,
#  'token[0]=Christie': 8531,
#  'token[0]=soldiers': 8598,
#  'token[1]=body': 11114,
#  'token[1]=Syria': 11899,
#  'token[-2]=before': 949,
#  'token[-1]=EU': 6511,
#  'token[3]=73': 4268,
#  'token[-2]=Commonwealth': 9451,
#  'token[1]=STANDINGS': 3781,
#  'token[2]=76': 7412,
#  'token[-1]=Hanwha': 14343,
#  'token[3]=Canadian': 9302,
#  'token[2]=armed': 7427,
#  'token[0]=pct': 2575,
#  'token[-2]=sets': 8966,
#  'token[1]=night': 3427,
#  'token[2]=SCHEDULE': 9803,
#  'token[-3]=February': 9546,
#  'token[-1]=ambassador': 12285,
#  'token[-3]=Irish': 11649,
#  'token[-2]=Tony': 14613,
#  'token[-1]=business': 3719,
#  'token[-2]=towns': 14725,
#  'token[-2]=Marseille': 10744,
#  'token[3]=Khartoum': 13055,
#  'token[-2]=accused': 3916,
#  'token[2]=centre': 6167,
#  'token[-1]=join': 10661,
#  'token[3]=territory': 8777,
#  'token[-3]=Kong': 3010,
#  'token[0]=inning': 5854,
#  'token[2]=majority': 11246,
#  'token[1]=Party': 3035,
#  'token[-1]=previous': 3905,
#  'token[-2]=problems': 8961,
#  'token[0]=rival': 8594,
#  'token[-2]=44': 13334,
#  'token[-2]=Daewoo': 14550,
#  'token[3]=bit': 13078,
#  'token[0]=ROUND': 11776,
#  'token[1]=become': 7732,
#  'token[3]=medical': 10554,
#  'token[-3]=championship': 3928,
#  'token[-1]=61-2': 11378,
#  'token[-3]=killing': 7637,
#  'token[3]=with': 327,
#  'token[-2]=up': 654,
#  'token[0]=Co': 3938,
#  'token[-1]=Jul': 10608,
#  'token[-2]=reserve': 13464,
#  'token[3]=yet': 4822,
#  'token[-2]=use': 5800,
#  'token[0]=traffic': 8129,
#  'token[-2]=plane': 4719,
#  'token[1]=County': 9153,
#  'token[-1]=Queen': 13206,
#  'token[3]=become': 7839,
#  'token[-3]=home': 1551,
#  'token[-3]=feed': 9586,
#  'token[1]=heavy': 10372,
#  'token[0]=Gaza': 9641,
#  'token[-3]=hits': 3931,
#  'token[1]=continue': 6139,
#  'token[1]=often': 10384,
#  'token[2]=come': 4963,
#  'token[-3]=seized': 7289,
#  'token[-3]=point': 5611,
#  'token[0]=deficit': 7019,
#  'token[0]=Tim': 10264,
#  'token[1]=could': 975,
#  'token[2]=aggregate': 6164,
#  'token[-3]=signed': 3761,
#  'token[1]=joined': 10376,
#  'token[-2]=soon': 6594,
#  'token[0]=parties': 6110,
#  'token[-2]=kg': 14680,
#  'token[-2]=six': 1228,
#  'token[0]=KDP': 9070,
#  'token[3]=must': 6199,
#  'token[-2]=sale': 8963,
#  'token[-3]=challenge': 13560,
#  'token[-2]=Miguel': 14579,
#  'token[3]=big': 6804,
#  'token[-1]=Human': 12242,
#  'token[2]=dealer': 10440,
#  'token[2]=sign': 8237,
#  'token[-1]=FLORIDA': 9954,
#  'token[3]=six': 1209,
#  'token[-2]=Rating': 14601,
#  'token[-2]=Inc.': 12389,
#  'token[-3]=sent': 4198,
#  'token[1]=Germany': 1039,
#  'token[0]=look': 11017,
#  'token[-2]=men': 3216,
#  'token[-1]=Diana': 9953,
#  'token[3]=67': 3985,
#  'token[-2]=similar': 6593,
#  'token[0]=lost': 1357,
#  'token[2]=player': 7102,
#  'token[-3]=member': 8502,
#  'token[-1]=men': 3207,
#  'token[1]=measures': 9768,
#  'token[2]=dangerous': 12035,
#  'token[-2]=economy': 6915,
#  'token[-2]=life': 11582,
#  'token[-3]=deals': 13567,
#  'token[1]=National': 2196,
#  'token[-1]=Bremen': 14319,
#  'token[-3]=completed': 6962,
#  'token[-3]=Scotland': 8997,
#  'token[-3]=county': 13564,
#  'token[2]=mixed': 14101,
#  'token[0]=west': 11858,
#  'token[3]=provide': 12182,
#  'token[0]=bus': 9669,
#  'token[-1]=Korea': 9377,
#  'token[1]=operation': 9209,
#  'token[-1]=heart': 10007,
#  'token[-3]=Cologne': 14759,
#  'token[0]=contract': 5273,
#  'token[0]=caught': 8098,
#  'token[2]=during': 1756,
#  'token[0]=common': 9671,
#  'token[1]=Britain': 1121,
#  'token[-2]=suspected': 10805,
#  'token[-3]=---': 11613,
#  'token[0]=low': 6684,
#  'token[1]=year': 651,
#  'token[0]=appeal': 7316,
#  'token[-1]=Council': 6509,
#  'token[3]=Tigers': 14196,
#  'token[-2]=against': 729,
#  'token[-3]=price': 3234,
#  'token[1]=big': 6397,
#  'token[3]=land': 7133,
#  'token[1]=Kremlin': 13865,
#  'postag[-2]=PDT': 4551,
#  'token[0]=CUP': 7658,
#  'token[0]=Toronto': 8554,
#  'token[0]=Cleveland': 14969,
#  'postag[-1]=$': 493,
#  'token[0]=levels': 5634,
#  'token[3]=Series': 9307,
#  'token[1]=chairman': 5658,
#  'token[-2]=Other': 14594,
#  'token[-1]=sets': 7932,
#  'token[-3]=great': 6625,
#  'token[1]=,': 67,
#  'token[-3]=Under': 13541,
#  'token[3]=higher': 3452,
#  'token[2]=rugby': 14120,
#  'token[-1]=largest': 8856,
#  'token[-1]=might': 4152,
#  'token[-2]=ransom': 13461,
#  'token[2]=using': 14141,
#  'token[2]=sell': 6178,
#  'token[0]=weekend': 2745,
#  'token[0]=really': 7338,
#  'token[1]=any': 1519,
#  'token[-3]=Police': 3656,
#  'token[2]=aimed': 11219,
#  'token[3]=here': 7132,
#  'token[-2]=right': 4315,
#  'token[0]=when': 751,
#  'token[1]=better': 5300,
#  'token[-2]=Teresa': 7965,
#  'token[-1]=cricket': 7176,
#  'token[0]=ahead': 3243,
#  'token[-3]=conditions': 6617,
#  'token[-1]=Jason': 10606,
#  'token[0]=team': 1561,
#  'token[-2]=suspect': 13474,
#  'token[1]=having': 6728,
#  'token[2]=95': 7413,
#  'token[-1]=faction': 13259,
#  'token[1]=shot': 4651,
#  'token[-3]=Canada': 4728,
#  'token[2]=Slovak': 12953,
#  'token[-1]=defeat': 6863,
#  'token[0]=Britain': 1027,
#  'postag[2]=VB': 94,
#  'token[3]=stay': 8774,
#  'token[1]=same': 2298,
#  'token[2]=operation': 9279,
#  'token[1]=II': 13857,
#  'token[-3]=where': 1377,
#  'token[-2]=Turkey': 8407,
#  'token[-2]=raised': 11597,
#  'token[-1]=67': 2305,
#  'token[0]=before': 943,
#  'token[1]=DIEGO': 8612,
#  'token[0]=stop': 8601,
#  'token[-3]=Slovakia': 5596,
#  'token[-1]=hard': 10006,
#  'token[2]=allowing': 8212,
#  'token[3]=P.': 11294,
#  'token[-1]=6-2': 2208,
#  'token[2]=groups': 5687,
#  'token[0]=penalty': 6369,
#  'token[-3]=200': 10140,
#  'token[2]=Ministry': 5128,
#  'token[1]=over': 687,
#  'token[-3]=bought': 9011,
#  'token[1]=they': 635,
#  'token[0]=still': 1662,
#  'token[0]=minority': 12761,
#  'token[-1]=Arab': 7157,
#  'token[3]=appeared': 9313,
#  'token[-1]=PAKISTAN': 7515,
#  'token[2]=rates': 5143,
#  'token[-1]=Austria': 3631,
#  'token[-3]=cost': 6963,
#  'token[-1]=UK': 13223,
#  'token[3]=summer': 8300,
#  'token[3]=father': 14233,
#  'token[3]=ruled': 11351,
#  'token[-1]=Rangers': 8325,
#  'token[1]=sets': 8188,
#  'token[-2]=damage': 9493,
#  'token[2]=working': 4124,
#  'postag[1]=TO': 124,
#  'token[0]=out': 655,
#  'token[-3]=hold': 4045,
#  'token[1]=couple': 7735,
#  'token[-3]=trip': 5829,
#  'token[1]=legal': 8175,
#  'token[1]=Belgium': 2094,
#  'token[1]=cricket': 7736,
#  'token[-3]=RTRS': 12555,
#  'token[2]=Peres': 11200,
#  'token[3]=Chile': 13046,
#  'token[2]=light': 10462,
#  'token[-3]=stories': 4467,
#  'token[0]=clear': 4913,
#  'token[-2]=2': 348,
#  'token[-1]=signed': 3729,
#  'token[3]=aircraft': 9898,
#  'token[0]=6-0': 5429,
#  'token[-1]=Cork': 8797,
#  'token[0]=Baghdad': 7304,
#  'token[0]=here': 6104,
#  'token[2]=increase': 7093,
#  'token[0]=Attendance': 2810,
#  'token[-2]=Australian': 2789,
#  'token[-1]=Ssangbangwool': 14393,
#  'token[1]=Khan': 6125,
#  'token[-2]=call': 5212,
#  'token[3]=said': 257,
#  'token[0]=houses': 10294,
#  'token[-2]=make': 2499,
#  'token[0]=These': 7010,
#  'token[2]=murder': 8714,
#  'token[0]=Ford': 12672,
#  'token[-3]=13': 2285,
#  'token[3]=66': 3984,
#  ...}

# %%
print(flat_dataset["train"][0]["features"])
tokenizer(flat_dataset["train"][0]["features"])
# Out:
# token[0]=EU postag[0]=NNP token[1]=rejects postag[1]=VBZ token[2]=German postag[2]=JJ token[3]=call postag[3]=NN first-letter-capitalized
# {'input_ids': [6343, 3, 1, 190, 2160, 42, 5516, 15, 2], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1]}

# %%
def encode(examples):
    return tokenizer(examples['features'])

dset_tokenized = flat_dataset.map(encode,batched=True,num_proc=4)

for key,val in dset_tokenized["train"][0].items():
    print(key,":",val)
# Out:
# Map (num_proc=4):   0%|          | 0/203621 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/51362 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/46435 [00:00<?, ? examples/s]
# tokens : EU
# pos_tags : 22
# chunk_tags : 11
# ner_tags : 3
# features : token[0]=EU postag[0]=NNP token[1]=rejects postag[1]=VBZ token[2]=German postag[2]=JJ token[3]=call postag[3]=NN first-letter-capitalized
# input_ids : [6343, 3, 1, 190, 2160, 42, 5516, 15, 2]
# attention_mask : [1, 1, 1, 1, 1, 1, 1, 1, 1]

# %% [markdown]
# # Labels
#
# There are three tasks in this dataset (POS, chunks, NER). So we want to choose one of them and create the "labels" key used by the trainer. So let's pick the POS task.

# %%
### EXRECISE 7 CODE BELOW - change the target from POS to NER

def assign_labels(ex):
    return {"labels":ex["ner_tags"]}
dset_tokenized=dset_tokenized.map(assign_labels,batched=True)
# Out:
# Map:   0%|          | 0/203621 [00:00<?, ? examples/s]
# Map:   0%|          | 0/51362 [00:00<?, ? examples/s]
# Map:   0%|          | 0/46435 [00:00<?, ? examples/s]

# %%
dset_tokenized["train"][0]
# Out:
# {'tokens': 'EU',
#  'pos_tags': 22,
#  'chunk_tags': 11,
#  'ner_tags': 3,
#  'features': 'token[0]=EU postag[0]=NNP token[1]=rejects postag[1]=VBZ token[2]=German postag[2]=JJ token[3]=call postag[3]=NN first-letter-capitalized',
#  'input_ids': [6343, 3, 1, 190, 2160, 42, 5516, 15, 2],
#  'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1],
#  'labels': 3}

# %% [markdown]
# ---
#
# # MLP model
#
# With the data now ready, we'll build the MLP model. Note that this is _identical_ to the MLP model we used for text classification: the only difference between the two applications is in the data.
#
# The model class in its simplest form has `__init__()` which instantiates the layers and `forward()` which implements the actual computation. For more information on these, please see the [PyTorch turorial](https://pytorch.org/tutorials/beginner/introyt/modelsyt_tutorial.html).

# %%
# A Transformers library model wants a config,
# I can simply inherit from the base
# class for pretrained configs
# We don't really need to do anything very special
class MLPConfig(transformers.PretrainedConfig):
    pass

# This is the model
class MLP(transformers.PreTrainedModel):

    config_class=MLPConfig

    # In the initialization method, one instantiates the layers
    # these will be, for the most part the trained parameters of the model
    def __init__(self,config):
        super().__init__(config)
        self.all_tied_weights_keys = {} #Annoying bug in Transformers, must have this here or else we crash on saved model load
        #### HERE WE CREATE THE MODEL'S LAYERS:
        self.vocab_size=config.vocab_size #embedding matrix row count
        # Build and initialize embedding of vocab size x hidden size
        assert tokenizer.vocab["[PAD]"]==0 #let's make sure our assumption of pad==0 holds!

        self.embedding=torch.nn.Embedding(num_embeddings=self.vocab_size,embedding_dim=config.hidden_size,padding_idx=0)
        # Initialize the embeddings to random values
        # Note! This function is relatively clever and keeps the embedding for 0, the padding, pure zeros
        torch.nn.init.uniform_(self.embedding.weight.data,-0.001,0.001) #initialize the embeddings with small random values

        # This takes care of the lower half of the network, now the upper half
        # Output layer: hidden size x output size
        self.output=torch.nn.Linear(in_features=config.hidden_size,out_features=config.nlabels)
        # Now we have the parameters of the model
        self.loss=torch.nn.CrossEntropyLoss() #This loss is meant for classification, so let's use it


    # The computation of the model is put into the forward() function
    # it receives a batch of data and optionally the correct `labels`
    #
    # If given `labels` it returns (loss,output)
    # if not, then it returns (output,)
    def forward(self,input_ids,labels=None,**kwargs):
        #1) sum up the embeddings of the items
        embedded=self.embedding(input_ids) #(batch,ids)->(batch,ids,embedding_dim)
        # Since the Embedding keeps the first row of the matrix pure zeros, we don't need to worry about the padding
        # so next we sum the embeddings across the word dimension
        # (batch,ids,embedding_dim) -> (batch,embedding_dim)
        embedded_summed=torch.sum(embedded,dim=1)

        #2) apply non-linearity
        # (batch,embedding_dim) -> (batch,embedding_dim)
        projected=torch.tanh(embedded_summed) #Note how non-linearity is applied here and not when configuring the layer in __init__()
        # projected=embedded_summed ## If you need to bypass non-linearity, use this :)
        #3) and now apply the upper, output layer of the network
        # (batch,embedding_dim) -> (batch, num_of_classes i.e. 2 in our case)
        logits=self.output(projected)

        # ...and that's all there is to it!

        #print("input_ids.shape",input_ids.shape)
        #print("embedded.shape",embedded.shape)
        #print("embedded_summed.shape",embedded_summed.shape)
        #print("projected.shape",projected.shape)
        #print("logits.shape",logits.shape)

        # If we have labels, we ought to calculate the loss
        if labels is not None:

            # You run it as loss(model_output,correct_labels)
            return (self.loss(logits,labels),logits) #2-tuple, i.e. pair of values returned
        else:
            # No labels, so just return the logits
            return (logits,) #this weird syntax means 1-tuple

# %% [markdown]
# Configure the model

# %%
### EXERCISE 7 CODE - must reconfigure nlabels
num_labels = len(NER2ID)

mlp_config = MLPConfig(
    vocab_size=len(tokenizer.vocab),
    hidden_size=20,
    nlabels=num_labels
)

print("mlp_config:", mlp_config)
# Out:
# mlp_config: MLPConfig {
#   "hidden_size": 20,
#   "nlabels": 9,
#   "transformers_version": "5.5.3",
#   "vocab_size": 15000
# }

# %% [markdown]
# ---
#
# # Train the model
#
# We will use the Hugging Face [Trainer](https://huggingface.co/docs/transformers/main_classes/trainer) class for training
#
# * Loads of arguments that control the training
# * Configurable metrics to evaluate performance
# * Data collator builds the batches
# * Early stopping callback stops when eval loss no longer improves
# * Model load/save
# * Good foundation for later deep learning course

# %% [markdown]
# First, let's create a [`TrainingArguments`](https://huggingface.co/docs/transformers/v4.17.0/en/main_classes/trainer#transformers.TrainingArguments) object to specify hyperparameters and various other settings for training.
#
# Printing this simple dataclass object will show not only the values we set, but also the defaults for all other arguments. Don't worry if you don't understand what all of these do! Many are not relevant to us here, and you can find the details in [`Trainer` documentation](https://huggingface.co/docs/transformers/main_classes/trainer) if you are interested.

# %%
trainer_args = transformers.TrainingArguments(
    "mlp_checkpoints", #save checkpoints here
    eval_strategy="steps",
    logging_strategy="steps",
    eval_steps=1000,
    logging_steps=1000,
    save_steps=1000,
    learning_rate=5e-4, #learning rate of the gradient descent
    max_steps=20000,
    load_best_model_at_end=True,
    per_device_train_batch_size=16
)

pprint(trainer_args)
# Out:
# TrainingArguments(
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# average_tokens_across_devices=True,
# batch_eval_metrics=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=False,
# enable_jit_checkpoint=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_on_start=False,
# eval_steps=1000,
# eval_strategy=IntervalStrategy.STEPS,
# eval_use_gather_object=False,
# fp16=False,
# fp16_full_eval=False,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=False,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=None,
# hub_revision=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_for_metrics=[],
# include_num_input_tokens_seen=no,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=0.0005,
# length_column_name=length,
# liger_kernel_config=None,
# load_best_model_at_end=True,
# local_rank=-1,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=None,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=1000,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs=None,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=20000,
# metric_for_best_model=loss,
# neftune_noise_alpha=None,
# num_train_epochs=3.0,
# optim=OptimizerNames.ADAMW_TORCH_FUSED,
# optim_args=None,
# optim_target_modules=None,
# output_dir=mlp_checkpoints,
# parallelism_config=None,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=16,
# prediction_loss_only=False,
# project=huggingface,
# push_to_hub=False,
# remove_unused_columns=True,
# report_to=[],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=None,
# save_on_each_node=False,
# save_only_model=False,
# save_steps=1000,
# save_strategy=SaveStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_empty_cache_steps=None,
# trackio_space_id=trackio,
# train_sampling_strategy=random,
# use_cache=False,
# use_cpu=False,
# use_liger_kernel=False,
# warmup_ratio=None,
# warmup_steps=0,
# weight_decay=0.0,
# )

# %% [markdown]
# Next, let's create a metric for evaluating performance during and after training. We can use the convenience function [`load_metric`](https://huggingface.co/docs/datasets/about_metrics) to load one of many pre-made metrics and wrap this for use by the trainer.
#
# We can use the basic `accuracy` metric, defined as the proportion of correctly predicted labels out of all labels. This time, though, the data is not evenly split.

# %%
import numpy as np
import evaluate

accuracy = evaluate.load("accuracy")

def compute_accuracy(outputs_and_labels):
    outputs, labels = outputs_and_labels
    predictions = np.argmax(outputs, axis=-1) #pick the index of the "winning" label
    return accuracy.compute(predictions=predictions, references=labels)

# %% [markdown]
# We can then create the `Trainer` and train the model by invoking the [`Trainer.train`](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Trainer.train) function.
#
# In addition to the model, the settings passed in through the `TrainingArguments` object created above (`trainer_args`), the data, and the metric defined above, we create and pass the following to the `Trainer`:
#
# * [data collator](https://huggingface.co/docs/transformers/main_classes/data_collator): groups input into batches
# * [`EarlyStoppingCallback`](https://huggingface.co/docs/transformers/main_classes/callback#transformers.EarlyStoppingCallback): stops training when performance stops improving

# %%
# Make a new model
mlp = MLP(mlp_config)


# Argument gives the number of steps of patience before early stopping
# i.e. training is stopped when the evaluation loss fails to improve
# certain number of times
early_stopping = transformers.EarlyStoppingCallback(5)

trainer = transformers.Trainer(
    model=mlp,
    args=trainer_args,
    train_dataset=dset_tokenized["train"],
    eval_dataset=dset_tokenized["validation"].select(range(1000)),
    compute_metrics=compute_accuracy,
    data_collator=transformers.DataCollatorWithPadding(tokenizer),
    callbacks=[early_stopping]
)

trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='20000' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20000/20000 02:25, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.685405</td>
#       <td>0.629080</td>
#       <td>0.784000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.365697</td>
#       <td>0.519779</td>
#       <td>0.839000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.305782</td>
#       <td>0.453581</td>
#       <td>0.864000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.260841</td>
#       <td>0.406702</td>
#       <td>0.877000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.229526</td>
#       <td>0.371390</td>
#       <td>0.889000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.218379</td>
#       <td>0.336576</td>
#       <td>0.895000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.184642</td>
#       <td>0.321637</td>
#       <td>0.894000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.184943</td>
#       <td>0.287098</td>
#       <td>0.900000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.179081</td>
#       <td>0.272750</td>
#       <td>0.910000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.163545</td>
#       <td>0.269946</td>
#       <td>0.912000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.168226</td>
#       <td>0.254044</td>
#       <td>0.911000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.163488</td>
#       <td>0.244892</td>
#       <td>0.919000</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.149963</td>
#       <td>0.239152</td>
#       <td>0.923000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.136521</td>
#       <td>0.234175</td>
#       <td>0.922000</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.142752</td>
#       <td>0.229365</td>
#       <td>0.924000</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.133822</td>
#       <td>0.227797</td>
#       <td>0.926000</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.134131</td>
#       <td>0.221977</td>
#       <td>0.927000</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.134886</td>
#       <td>0.218607</td>
#       <td>0.927000</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.126737</td>
#       <td>0.217771</td>
#       <td>0.928000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.131353</td>
#       <td>0.217287</td>
#       <td>0.928000</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=20000, training_loss=0.20998598022460938, metrics={'train_runtime': 145.5396, 'train_samples_per_second': 2198.715, 'train_steps_per_second': 137.42, 'total_flos': 5369469588.0, 'train_loss': 0.20998598022460938, 'epoch': 1.571462245619549})

# %% [markdown]
# That's pretty poor performance for a task as simple as POS tagging where state-of-the-art accuracies are generally 97-99%. (The approach demonstrated in this notebook should be considered more of a teaching tool than a serious tagger implementation.)
#
# However, the result is certainly much better than random, so we can conclude that the model is learning something about the task.

# %% [markdown]
# ---
#
# # What has the model learned?
#
# * The embeddings should have some meaning to them
# * Similar features should have similar embeddings

# %%
# Grab the embedding matrix out of the trained model
# and drop the first row (padding 0)
# then we can treat the embeddings as vectors

weights=mlp.embedding.weight.detach().cpu().numpy()

# %%
import sklearn
qry_idx=tokenizer.vocab["token[0]=John"]
idx2feat={v:k for k,v in tokenizer.vocab.items()}

#calculate the distance of the "in" embedding to all other embeddings
distance_to_qry=sklearn.metrics.pairwise.euclidean_distances(weights[qry_idx:qry_idx+1,:],weights)
nearest_neighbors=np.argsort(distance_to_qry) #indices of words nearest to "in"
for nearest in nearest_neighbors[0,:20]:
    print(idx2feat[nearest])
# Out:
# token[0]=John
# token[0]=Paul
# token[-1]=1.
# token[0]=David
# token[0]=M.
# token[0]=A.
# token[0]=Michael
# token[0]=Mark
# token[-1]=c
# token[1]=Ahmed
# token[0]=Wasim
# token[1]=Akram
# token[-1]=champion
# token[0]=Dole
# token[0]=Dutroux
# token[0]=Yeltsin
# token[0]=Peter
# token[-1]=4.
# token[-1]=5.
# token[0]=Arafat

# %% [markdown]
# * The embeddings indeed seem to reflect the task and capture aspects of the meaning of words relevant to the task
# * But now we have many classes, so we should take that into account too
# * We can take the dot-product of the feature embeddings with the output layer weight of the class we care about
# * When you think how the information propagates in the network, this will give us a single number reflecting each feature w.r.t. the selected label
# * Technically speaking, it is the prediction of an example which only has that one feature, with respect to that one class
# * Here is how we can implement it (here we rely on the fact that the model is linear, since we didn't include a nonlinearity earlier in the model's `forward()`

# %%
import numpy

embedding_weights=weights    #shape (features, embedding-dim)
output_weights=mlp.output.weight.detach().cpu().numpy()    #shape (num-labels, embedding-dim)

# We just matrix-multiply these together, since this gives us all the dot-products
weights_by_label=numpy.matmul(numpy.tanh(embedding_weights), output_weights.T)
weights_by_label.shape
# Out:
# (15000, 9)

# %%
### EXERCISE 7 CODE BELOW: changes from POS to NER

def get_most_important_features_for_and_against(label):
    label_idx = NER2ID[label]
    feature_weights = weights_by_label[:,label_idx] #pick the column that interests us

    #The shape of feature_weights is (feature_vocab_size,) i.e. it is a vector
    features_weight_idx = numpy.argsort(-feature_weights) #sort in descending order, this will be vector of indices
    features_for = [idx2feat[feature_idx] for feature_idx in features_weight_idx[:30]]
    features_against = [idx2feat[feature_idx] for feature_idx in features_weight_idx[-30:][::-1]]
    return features_for, features_against

for label in NER2ID:
    dt_plus,dt_minus=get_most_important_features_for_and_against(label)
    print(f"{label}")
    print(f"Most important features *for* label {label}:")
    pprint("   ".join(dt_plus))
    print()
    print(f"Most important features *against* label {label}:")
    pprint("   ".join(dt_minus))
    print("\n------\n")
# Out:
# O
# Most important features *for* label O:
# ('token[0]=0   token[0]=to   token[0]=a   token[0]=AT   postag[0]=PRP   '
#  'token[0]=said   token[0]=which   token[0]=2   token[0]=$   postag[0]="   '
#  'token[0]="   token[0]=He   token[0]=Tuesday   token[0]=Thursday   '
#  'postag[0]=PRP$   token[0]=4   token[0]=who   token[0]=Monday   '
#  'token[0]=July   token[0]=President   token[0]=Minister   '
#  'token[0]=Wednesday   postag[0]=:   token[0]=It   token[0]=was   '
#  'token[0]=June   token[0]=has   token[0]=3   token[0]=.   token[0]=first')
#
# Most important features *against* label O:
# ('first-letter-capitalized   token[0]=de   token[0]=&   token[0]=German   '
#  'token[0]=Russian   token[0]=U.S.   token[0]=British   token[0]=French   '
#  'token[0]=Israeli   token[0]=Palestinian   token[0]=Iraqi   token[-1]=beat   '
#  'token[0]=European   token[3]=0   token[-1]=At   token[-1]=Lloyd   '
#  'token[0]=Dutch   token[1]=Oval   token[0]=RTRS   token[-1]=RUGBY   '
#  'token[0]=1,000   token[1]=Co   token[-1]=New   token[0]=Olympic   '
#  'token[0]=South   token[-1]=CDU   token[-1]=South   token[0]=Britain   '
#  'token[0]=Clinton   token[0]=Iraq')
#
# ------
#
# B-PER
# Most important features *for* label B-PER:
# ('token[-1]=President   token[-1]=Minister   token[0]=Clinton   token[-1]=b   '
#  'token[-1]=2.   token[-1]=3.   token[0]=Mark   token[-1]=6.   token[0]=M.   '
#  'token[-1]=1.   token[0]=John   token[0]=Michael   token[2]=c   '
#  'token[-1]=5.   token[0]=Yeltsin   token[0]=Paul   token[-1]=c   '
#  'token[0]=A.   token[0]=David   token[0]=Arafat   token[1]=Ahmed   '
#  'token[0]=Dole   token[-2]=Prime   token[0]=Dutroux   token[0]=Lebed   '
#  'token[-1]=champion   token[3]=France   token[-1]=4.   token[-1]=7.   '
#  'token[0]=Peter')
#
# Most important features *against* label B-PER:
# ('postag[0]=PRP   token[0]=to   token[0]=who   token[0]=which   token[0]="   '
#  'token[0]=AT   postag[0]="   token[0]=a   token[0]=0   token[0]=He   '
#  'postag[0]=:   token[0]=Thursday   token[0]=It   token[0]=Wednesday   '
#  'token[0]=President   token[0]=$   token[0]=Tuesday   token[0]=Monday   '
#  'postag[0]=PRP$   token[0]=was   token[0]=.   postag[0]=IN   '
#  'token[0]=Minister   token[0]=July   postag[1]=NNS   postag[0]=.   '
#  'token[0]=has   token[0]=said   token[0]=that   token[0]=he')
#
# ------
#
# I-PER
# Most important features *for* label I-PER:
# ('token[-2]=President   postag[-1]=NNP   token[-2]=Minister   token[-1]=M.   '
#  'token[-1]=Mark   token[-1]=John   token[2]=Spain   token[-1]=Paul   '
#  'token[-1]=Michael   token[0]=Ahmed   token[-3]=Prime   token[-2]=2.   '
#  'token[0]=Akram   token[-1]=A.   token[-2]=1.   token[-1]=David   '
#  'token[-2]=vs.   token[1]=through   token[1]=c   token[-1]=Peter   '
#  'token[3]=Newsroom   token[-2]=3.   token[-1]=Bill   token[-2]=champion   '
#  'token[-1]=Waqar   token[-1]=G.   token[-1]=Alexander   token[-2]=beat   '
#  'token[-1]=Steve   token[-1]=Wasim')
#
# Most important features *against* label I-PER:
# ('postag[0]=PRP   postag[0]=CD   token[0]=said   token[0]=AT   token[0]=0   '
#  'token[0]=to   token[0]=DIVISION   token[0]=3   token[0]=has   '
#  'postag[0]=NNS   token[0]=2   token[0]=4   token[0]=a   token[0]=was   '
#  'token[0]=.   postag[0]="   token[0]=Minister   token[0]="   token[0]=which   '
#  'token[0]=1996-08-28   postag[1]=NNP   postag[0]=VBD   token[0]=The   '
#  'postag[0]=PRP$   postag[0]=.   token[0]=He   token[0]=Monday   token[0]=$   '
#  'token[0]=Tuesday   postag[1]=NNS')
#
# ------
#
# B-ORG
# Most important features *for* label B-ORG:
# ('token[0]=Reuters   token[-1]=v   token[1]=Newsroom   token[-1]=0   '
#  'token[0]=U.N.   token[-1]=told   first-letter-capitalized   token[1]=0   '
#  'token[-1]=1   token[1]=v   token[0]=Ajax   token[-1]=3   token[-1]=2   '
#  'token[3]=1   token[0]=St   token[0]=NATO   token[1]=Corp   token[3]=v   '
#  'token[0]=PSV   token[0]=PUK   token[3]=0   token[0]=EU   token[-3]=v   '
#  'token[1]=3   token[1]=2   token[1]=Union   token[0]=OSCE   token[2]=0   '
#  'token[1]=AT   token[2]=21')
#
# Most important features *against* label B-ORG:
# ('postag[-1]=NNP   token[0]=0   token[0]=1   token[0]=to   token[0]=2   '
#  'token[0]=a   postag[0]=:   token[0]=$   token[0]=which   token[0]=beat   '
#  'postag[0]="   token[0]="   token[0]=4   token[0]=AT   token[0]=He   '
#  'token[0]=who   token[0]=President   token[0]=Thursday   token[0]=It   '
#  'token[0]=Tuesday   postag[0]=PRP$   token[0]=July   postag[0]=CD   '
#  'token[0]=3   token[0]=Monday   token[0]=Wednesday   token[0]=September   '
#  'token[0]=government   token[0]=June   token[0]=said')
#
# ------
#
# I-ORG
# Most important features *for* label I-ORG:
# ('token[0]=Inc   postag[-1]=NNP   token[0]=Newsroom   token[0]=Corp   '
#  'token[-1]=St   token[0]=Co   token[0]=Party   token[1]=0   token[1]=Inc   '
#  'token[0]=YORK   token[0]=Union   token[1]=4   token[1]=3   token[-1]=NEW   '
#  'token[0]=Commission   postag[-1]=NNPS   token[1]=Co   token[0]=of   '
#  'token[1]=Commission   token[-1]=New   token[-1]=&   token[-1]=SAN   '
#  'token[2]=0   token[1]=2   token[0]=Ltd   token[0]=Bank   token[3]=0   '
#  'token[-1]=National   token[1]=Ltd   token[0]=Exchange')
#
# Most important features *against* label I-ORG:
# ('token[0]=0   token[-1]=AT   token[0]=3   token[0]=2   token[0]=said   '
#  'token[0]=4   token[0]=to   token[0]=AT   postag[0]=CD   token[0]=1   '
#  'token[0]=was   token[0]=a   token[0]=has   postag[0]=PRP   '
#  'token[0]=Minister   token[0]=The   token[0]=LONDON   token[0]=1996-08-28   '
#  'token[0]=which   token[0]="   postag[0]="   postag[0]=VBD   '
#  'token[0]=Britain   token[0]=He   postag[0]=:   token[0]=$   token[0]=from   '
#  'postag[0]=PRP$   postag[0]=VBN   token[0]=But')
#
# ------
#
# B-LOC
# Most important features *for* label B-LOC:
# ('token[0]=Britain   token[0]=England   token[-1]=AT   token[0]=Germany   '
#  'token[1]=1996-08-28   token[0]=U.S.   token[0]=Pakistan   '
#  'token[1]=1996-08-27   token[1]=1996-08-26   token[0]=China   '
#  'token[1]=1996-08-29   token[0]=Italy   token[1]=1996-08-23   '
#  'token[1]=1996-08-22   token[0]=Iraq   token[0]=Russia   token[0]=Australia   '
#  'token[1]=1996-08-25   token[0]=LONDON   token[0]=France   '
#  'token[1]=1996-08-24   token[0]=Belgium   token[0]=Israel   '
#  'token[1]=newsroom   token[0]=Sweden   token[0]=Spain   token[0]=Japan   '
#  'token[1]=States   token[0]=India   token[-1]=At')
#
# Most important features *against* label B-LOC:
# ('token[0]=a   token[0]=to   token[0]=AT   token[0]=Wednesday   '
#  'token[0]=July   token[0]=Tuesday   token[0]=Thursday   token[0]=which   '
#  'token[0]=$   token[0]=June   token[0]=Monday   postag[0]=PRP   token[0]=0   '
#  'postag[-1]=NNP   token[0]=President   postag[0]=PRP$   token[0]=He   '
#  'token[0]=Sunday   token[0]=September   token[0]=Friday   postag[0]=:   '
#  'token[0]=who   token[0]=It   token[0]=August   token[0]="   postag[0]="   '
#  'token[0]=Minister   token[0]=But   token[0]=first   token[0]=government')
#
# ------
#
# I-LOC
# Most important features *for* label I-LOC:
# ('token[-1]=South   token[-1]=New   token[0]=YORK   postag[-1]=NNP   '
#  'token[-1]=NEW   token[0]=Africa   token[0]=States   token[-1]=West   '
#  'token[-1]=Hong   token[0]=Kong   token[0]=Republic   token[0]=Lanka   '
#  'token[-1]=United   token[-1]=Sri   token[-1]=Czech   token[0]=Zealand   '
#  'token[-1]=Costa   token[-1]=SAN   token[0]=York   token[0]=African   '
#  'token[-1]=San   token[0]=City   token[-2]=AT   token[0]=CITY   '
#  'token[0]=Rica   token[1]=1996-08-28   token[1]=1996-08-26   token[0]=of   '
#  'token[0]=Bank   token[-2]=at')
#
# Most important features *against* label I-LOC:
# ('token[0]=said   postag[0]=PRP   token[0]=to   token[0]=0   token[0]=AT   '
#  'token[0]=a   token[0]=3   token[0]=2   token[0]=4   token[0]=Minister   '
#  'token[0]=which   token[0]=was   token[0]=has   token[0]=$   postag[0]=PRP$   '
#  'token[0]=Tuesday   token[0]="   postag[0]="   token[0]=1996-08-28   '
#  'token[0]=Monday   token[0]=Thursday   token[0]=July   token[0]=He   '
#  'token[0]=But   token[0]=first   postag[0]=CD   token[0]=June   '
#  'token[0]=President   token[0]=.   token[0]=who')
#
# ------
#
# B-MISC
# Most important features *for* label B-MISC:
# ('token[0]=Russian   token[0]=German   token[0]=GMT   postag[0]=$   '
#  'token[0]=Australian   token[1]=Open   token[1]=Cup   token[0]=British   '
#  'token[0]=French   token[0]=American   token[0]=Israeli   '
#  'first-letter-capitalized   token[1]=LEAGUE   token[1]=League   '
#  'token[0]=English   token[0]=Moslem   token[0]=Bosnian   token[0]=Iraqi   '
#  'token[0]=Olympic   token[2]=DIVISION   token[0]=Dutch   token[0]=Italian   '
#  'token[0]=European   token[0]=Cup   token[0]=Japanese   '
#  'token[0]=Palestinian   token[0]=Sudanese   token[0]=Chinese   '
#  'token[0]=Serb   token[0]=Iranian')
#
# Most important features *against* label B-MISC:
# ('token[0]=a   token[0]=to   token[0]=first   token[0]=0   token[0]=$   '
#  'token[0]=second   postag[0]="   token[0]="   token[0]=AT   token[0]=which   '
#  'postag[0]=PRP$   postag[0]=PRP   token[0]=last   token[0]=said   '
#  'token[0]=He   token[0]=Tuesday   token[0]=Thursday   token[0]=Wednesday   '
#  'token[0]=who   token[0]=was   token[0]=government   token[0]=It   '
#  'token[0]=his   token[0]=.   token[0]=Monday   token[0]=July   '
#  'token[0]=President   token[0]=an   token[0]=new   token[0]=But')
#
# ------
#
# I-MISC
# Most important features *for* label I-MISC:
# ('token[0]=Cup   postag[-1]=NNP   token[-1]=South   token[0]=Open   '
#  'token[-1]=World   token[0]=League   token[0]=African   token[1]=Cup   '
#  'token[-1]=Grand   token[0]=OPEN   token[0]=CUP   token[-1]=NEW   '
#  'token[0]=LEAGUE   token[-2]=AT   token[-1]=MAJOR   token[-1]=Sri   '
#  'token[0]=YORK   token[2]=tournament   token[-1]=New   token[-1]=National   '
#  'token[0]=German   token[0]=Serb   token[-3]=RESULTS   token[0]=Russian   '
#  'token[0]=Kurdish   token[0]=GMT   token[0]=DIVISION   token[-1]=WESTERN   '
#  'postag[-3]=DT   token[0]=Korean')
#
# Most important features *against* label I-MISC:
# ('token[0]=said   token[0]=Reuters   postag[0]=PRP   token[0]=AT   '
#  'token[0]=The   token[0]=a   token[0]=to   token[-1]=2   token[0]=0   '
#  'token[0]=1996-08-28   token[-1]=3   token[-1]=1   postag[0]=VBN   '
#  'token[0]=was   token[0]=Minister   token[1]=AT   postag[0]=NN   '
#  'token[0]=has   token[0]=3   token[0]=4   postag[0]=PRP$   postag[0]=VBD   '
#  'token[0]=first   token[0]=1996-08-22   token[0]=1996-08-29   token[-1]=0   '
#  'token[0]=which   token[0]=1996-08-27   token[0]=$   token[-1]=AT')
#
# ------
